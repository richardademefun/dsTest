# %% [markdown]
# # Demographic data

# %% [markdown]
# Here i want to have a look at whether are any trend in ziplocations and whether people are more suseptible to ads. to do this i will map the zip codes to their respective lat long and look at the heatmap distributon on a map

# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
from itertools import product
from scipy.stats import f_oneway
from sklearn.metrics import mean_absolute_error, mean_squared_error, auc
def NormalizeData(data):
    return ((data - np.min(data)) / (np.max(data) - np.min(data)) * 50)  + 50
import matplotlib.pyplot as plt

# %%
all_data = pd.read_csv("./test_param_performance.csv")
# Out:
# /home/richard/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3172: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
all_data
# Out:
#          advertiser_id  insertion_order_id  line_item_id device_type  \
# 0              5195404             5407889      13917115      Mobile
# 1              5195404             5407889      13917115      Mobile
# 2              5195404             5407889      13917115      Mobile
# 3              5195404             5407889      13917115      Mobile
# 4              5195404             5407889      13917115      Mobile
# ...                ...                 ...           ...         ...
# 3675482        5195404             5407889      16423703     Tablets
# 3675483        5195404             5407889      16423703     Tablets
# 3675484        5195404             5407889      16423703     Tablets
# 3675485        5195404             5407889      16423703     Tablets
# 3675486        5195404             5407889      16423703     Tablets
#
#          weekday_user_tz  hour_user_tz country region    city  dma  \
# 0                      0             0      US     MI  191098  563
# ...

# %%
all_data['postal_code'] = all_data['postal_code'].astype(str)

# %%
zip_ctr = all_data.groupby('postal_code').agg({'ctr': 'mean'}).reset_index()

# %%
dem_data = pd.read_csv("../data/demographic_data.csv")

# %%
dem_data['Geographic Area Name'] = dem_data['Geographic Area Name'].astype(str)

# %%
dem_data.replace('-', 0, inplace=True)

# %%
all_data[all_data['postal_code'] =='---']
# Out:
#          advertiser_id  insertion_order_id  line_item_id device_type  \
# 12124          5195404             5407889      13917115      Mobile
# 31218          5195404             5407889      13917115      Mobile
# 35760          5195404             5407889      13917115      Mobile
# 40993          5195404             5407889      13917115      Mobile
# 44254          5195404             5407889      13917115      Mobile
# ...                ...                 ...           ...         ...
# 3635157        5195404             5407889      16344147      Mobile
# 3639086        5195404             5407889      16344147      Mobile
# 3652179        5195404             5407889      16344147      Mobile
# 3665891        5195404             5407889      16344147      Mobile
# 3667302        5195404             5407889      16344147      Mobile
#
#          weekday_user_tz  hour_user_tz country region    city  dma  \
# 12124                  1            17      US     MI  191501  553
# ...

# %%
merged = pd.merge(zip_ctr[['postal_code', 'ctr']], dem_data, left_on = 'postal_code', right_on = 'Geographic Area Name', how='outer')

# %% [markdown]
# Interestingly there are 3 zip codes present in the demographic data but not in the given data set

# %%
merged[(merged['postal_code']!=merged['postal_code']) | (merged['postal_code'] == '---')]
# Out:
#      postal_code       ctr  Unnamed: 0  \
# 0            ---  0.000272         NaN
# 1048         NaN       NaN       485.0
# 1049         NaN       NaN       988.0
# 1050         NaN       NaN       989.0
#
#      Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                   NaN
# 1048                                                  0
# 1049                                              117.2
# 1050                                              117.9
#
#       Estimate!!RACE!!Total population  \
# 0                                  NaN
# 1048                               0.0
# 1049                             886.0
# 1050                             960.0
#
#       Estimate!!RACE!!Total population!!One race  \
# 0                                            NaN
# 1048                                         0.0
# 1049                                       863.0
# ...

# %%
merged_clean = merged[(merged['postal_code'] == merged['postal_code']) & (merged['postal_code'] != '---')]

# %%
merged_clean.drop(['Geographic Area Name', 'Unnamed: 0', 'id'], axis=1, inplace=True)
# Out:
# /home/richard/anaconda3/envs/default/lib/python3.8/site-packages/pandas/core/frame.py:4162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
merged_clean[~merged_clean['postal_code'].isin(merged_clean.dropna()['postal_code'].to_list())]
# Out:
#     postal_code       ctr  \
# 31        48046  0.000000
# 40        48061  0.000000
# 47        48068  0.000000
# 65        48090  0.000000
# 74        48099  0.000000
# ..          ...       ...
# 872       49711  0.000616
# 883       49723  0.000000
# 894       49737  0.000000
# 896       49739  0.000154
# 929       49784  0.008621
#
#     Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 31                                                 NaN
# 40                                                 NaN
# 47                                                 NaN
# 65                                                 NaN
# 74                                                 NaN
# ..                                                 ...
# 872                                                NaN
# 883                                                NaN
# 894                                                NaN
# ...

# %% [markdown]
# I had a look through some of these instances where nan was present for all demographic columns  and i found that the ones i checked were for post codes where people don't live in the middle of nowhere. for example of of the zip codes was for a tiny area that had a church in it. therefore for these values i'm going to full all the nan with zero to specify that nobody lives here

# %%
merged_clean.fillna(0, inplace=True)
# Out:
# /home/richard/anaconda3/envs/default/lib/python3.8/site-packages/pandas/core/frame.py:4316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
merged_clean = merged_clean.astype(float)

# %% [markdown]
# Lets have a look at all the variables here. I want to see what variables correlate well will ctr and with each other to help me exclude veriables that could cause over fitting

# %% [markdown]
# # check if anythin correlates with ctr
# alas no

# %%
def trimm_correlated(df_in, threshold):
    df_corr = df_in.corr(method='pearson', min_periods=1)
    df_not_correlated = ~(df_corr.mask(np.tril(np.ones([len(df_corr)]*2, dtype=bool))).abs() > threshold).any()
    un_corr_idx = df_not_correlated.loc[df_not_correlated[df_not_correlated.index] == True].index
    df_out = df_in[un_corr_idx]
    return df_out

# %%
drimmed_dem_df = trimm_correlated(merged_clean, 0.9)

# %%
drimmed_dem_df
# Out:
#       postal_code       ctr  \
# 1         48001.0  0.002425
# 2         48002.0  0.001797
# 3         48003.0  0.000402
# 4         48005.0  0.001328
# 5         48006.0  0.001392
# ...           ...       ...
# 1043      49967.0  0.001876
# 1044      49968.0  0.001560
# 1045      49969.0  0.001288
# 1046      49970.0  0.000736
# 1047      49971.0  0.000309
#
#       Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 1                                                  87.0
# 2                                                  89.1
# 3                                                 108.5
# 4                                                  75.0
# 5                                                  95.9
# ...                                                 ...
# 1043                                              111.1
# 1044                                               76.2
# 1045                                               95.4
# ...

# %%
#drimmed_dem_df.to_csv("../data/non_colinear_demographic_data.csv")
